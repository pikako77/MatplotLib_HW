# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.legend import Legend

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
city_data = pd.read_csv(city_data_to_load)
ride_data = pd.read_csv(ride_data_to_load)

# %%
city_data.head()
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
city_data.dtypes
# Out:
# city            object
# driver_count     int64
# type            object
# dtype: object

# %%
ride_data.head()
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344

# %%
ride_data.dtypes
# Out:
# city        object
# date        object
# fare       float64
# ride_id      int64
# dtype: object

# %%
city_data.count()
# Out:
# city            120
# driver_count    120
# type            120
# dtype: int64

# %%
ride_data.count()
# Out:
# city       2375
# date       2375
# fare       2375
# ride_id    2375
# dtype: int64

# %%
# Combine the data into a single dataset
merged_data = pd.merge( ride_data,city_data,on = "city", how = "left")

# Display the data table for preview
merged_data.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
# check if data number is correct (should be 2375)

merged_data.count()
# Out:
# city            2375
# date            2375
# fare            2375
# ride_id         2375
# driver_count    2375
# type            2375
# dtype: int64

# %%
merged_data.dtypes
# Out:
# city             object
# date             object
# fare            float64
# ride_id           int64
# driver_count      int64
# type             object
# dtype: object

# %% [markdown]
# # Bubble Plot of Ride Sharing Data

# %%
merged_data
# Out:
#                      city                 date   fare        ride_id  \
# 0      Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1      South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2      Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3              Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4              South Jack  2018-03-06 04:28:35  34.58  3908451377344
# 5            South Latoya  2018-03-11 12:26:48   9.52  1994999424437
# 6           New Paulville  2018-02-27 11:17:56  43.25   793208410091
# 7            Simpsonburgh  2018-04-26 00:43:24  35.98   111953927754
# 8         South Karenland  2018-01-08 03:28:48  35.09  7995623208694
# 9           North Jasmine  2018-03-09 06:26:29  42.81  5327642267789
# 2370          Michaelberg  2018-04-29 17:04:39  13.38  8550365057598
# 2371      Lake Latoyabury  2018-01-30 00:05:47  20.76  9018727594352
# 2372          North Jaime  2018-02-10 21:03:50  11.11  2781339863778
# 2373         West Heather  2018-05-07 19:22:15  44.94  4256853490277
# 2374           Newtonview  2018-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# 4               46  Urban
# 5               10  Urban
# 6               44  Urban
# 7               21  Urban
# 8                4  Urban
# 9               33  Urban
# 10              33  Urban
# 11              48  Urban
# 12              34  Urban
# 13              48  Urban
# 14              47  Urban
# 15               6  Urban
# 16              46  Urban
# 17              17  Urban
# 18              70  Urban
# 19              33  Urban
# 20              47  Urban
# 21              44  Urban
# 22              25  Urban
# 23              49  Urban
# 24              45  Urban
# 25              73  Urban
# 26              28  Urban
# 27              23  Urban
# 28              37  Urban
# 29              10  Urban
# ...            ...    ...
# 2345             4  Rural
# 2346             4  Rural
# 2347             4  Rural
# 2348             7  Rural
# 2349             4  Rural
# 2350             7  Rural
# 2351             7  Rural
# 2352             9  Rural
# 2353             4  Rural
# 2354             7  Rural
# 2355             8  Rural
# 2356             2  Rural
# 2357             4  Rural
# 2358             2  Rural
# 2359             1  Rural
# 2360             1  Rural
# 2361             6  Rural
# 2362             8  Rural
# 2363             6  Rural
# 2364             4  Rural
# 2365             4  Rural
# 2366             8  Rural
# 2367             6  Rural
# 2368             4  Rural
# 2369             7  Rural
# 2370             6  Rural
# 2371             2  Rural
# 2372             1  Rural
# 2373             4  Rural
# 2374             1  Rural
#
# [2375 rows x 6 columns]

# %%
# group by city
groupby_type_city = merged_data.groupby(["type","city"]).agg({"fare":['sum','mean'],"ride_id":['count']})
#groupby_type_city = groupby_type_city()
groupby_type_city.head()
groupby_type_city
# Out:
#                                   fare            ride_id
#                                    sum       mean   count
# type     city
# Rural    Bradshawfurt           400.64  40.064000      10
#          Garzaport               72.37  24.123333       3
#          Harringtonfort         200.82  33.470000       6
#          Jessicaport            216.08  36.013333       6
#          Lake Jamie             206.15  34.358333       6
#          Lake Latoyabury        286.68  26.061818      11
#          Michaelberg            419.97  34.997500      12
#          New Ryantown           259.67  43.278333       6
#          Newtonview             146.98  36.745000       4
#          North Holly            262.17  29.130000       9
#          North Jaime            246.42  30.802500       8
#          Penaborough            176.23  35.246000       5
#          Randallchester         148.71  29.742000       5
#          South Jennifer         246.85  35.264286       7
#          South Marychester      334.96  41.870000       8
#          South Saramouth        144.64  36.160000       4
#          Taylorhaven            253.58  42.263333       6
#          West Heather           305.01  33.890000       9
# Suburban Barronchester          582.76  36.422500      16
#          Bethanyland            593.21  32.956111      18
#          Brandonfort            673.31  35.437368      19
#          Colemanland            679.68  30.894545      22
#          Davidfurt              543.93  31.995882      17
#          East Aaronbury         230.95  25.661111       9
#          East Danielview        536.53  31.560588      17
#          East Kentstad          387.70  29.823077      13
#          East Marymouth         832.55  30.835185      27
#          Grayville              416.45  27.763333      15
#          Josephside             887.17  32.858148      27
#          Lake Ann               370.68  30.890000      12
# ...                                ...        ...     ...
# Urban    Port Johnbury          506.14  23.006364      22
#          Port Samanthamouth     641.07  25.642800      25
#          Raymondhaven           537.01  21.480400      25
#          Reynoldsfurt           416.47  21.919474      19
#          Richardfort            626.45  22.373214      28
#          Roberthaven            569.50  23.729167      24
#          Robertport             461.21  23.060500      20
#          Rodneyfort             658.19  28.616957      23
#          Rogerston              486.15  22.097727      22
#          Royland                617.12  20.570667      30
#          Simpsonburgh           560.54  23.355833      24
#          South Evanton          828.51  26.726129      31
#          South Jack             436.34  22.965263      19
#          South Karenland       1008.35  26.535526      38
#          South Latoya           381.77  20.093158      19
#          South Michelleport     758.00  24.451613      31
#          South Phillip          885.71  28.571290      31
#          Valentineton           542.00  24.636364      22
#          West Angela           1013.61  25.990000      39
#          West Anthony           742.10  24.736667      30
#          West Christopherberg   634.95  24.421154      26
#          West Ericstad          402.25  22.347222      18
#          West Gabriel           467.96  20.346087      23
#          West Heidi             647.75  23.133929      28
#          West Josephberg        564.73  21.720385      26
#          West Patrickchester    451.73  28.233125      16
#          West Robert            778.84  25.123871      31
#          West Samuelburgh       544.19  21.767600      25
#          Williamsstad           560.33  24.362174      23
#          Williamsview           531.98  26.599000      20
#
# [120 rows x 3 columns]

# %%
 # calculate average fare per city
groupby_type_city["average_fare_per_city"] = merged_data.groupby(["type","city"])["fare"].mean()
groupby_type_city.head()
# Out:
#                         fare            ride_id driver_count      \
#                          sum       mean   count        count sum
# type  city
# Rural Bradshawfurt    400.64  40.064000      10           10  70
#       Garzaport        72.37  24.123333       3            3  21
#       Harringtonfort  200.82  33.470000       6            6  24
#       Jessicaport     216.08  36.013333       6            6   6
#       Lake Jamie      206.15  34.358333       6            6  24
#
#                      average_fare_per_city
#
# type  city
# Rural Bradshawfurt               40.064000
#       Garzaport                  24.123333
#       Harringtonfort             33.470000
#       Jessicaport                36.013333
#       Lake Jamie                 34.358333

# %%
# Calculate Total number of ride per city
groupby_type_city["ride_count_per_city"] = merged_data.groupby(["type","city"])["ride_id"].count()
groupby_type_city.head()
# Out:
#                         fare            ride_id driver_count      \
#                          sum       mean   count        count sum
# type  city
# Rural Bradshawfurt    400.64  40.064000      10           10  70
#       Garzaport        72.37  24.123333       3            3  21
#       Harringtonfort  200.82  33.470000       6            6  24
#       Jessicaport     216.08  36.013333       6            6   6
#       Lake Jamie      206.15  34.358333       6            6  24
#
#                      average_fare_per_city ride_count_per_city
#
# type  city
# Rural Bradshawfurt               40.064000                  10
#       Garzaport                  24.123333                   3
#       Harringtonfort             33.470000                   6
#       Jessicaport                36.013333                   6
#       Lake Jamie                 34.358333                   6

# %%
# Calculate Total number of ride per city
groupby_type_city["driver_count_per_city"] = merged_data.groupby(["type","city"])["ride_id"].count()
groupby_type_city.head()

# %%
groupby_type_city.reset_index()
groupby_type_city.head()
# Out:
#                         fare            ride_id average_fare_per_city
#                          sum       mean   count
# type  city
# Rural Bradshawfurt    400.64  40.064000      10             40.064000
#       Garzaport        72.37  24.123333       3             24.123333
#       Harringtonfort  200.82  33.470000       6             33.470000
#       Jessicaport     216.08  36.013333       6             36.013333
#       Lake Jamie      206.15  34.358333       6             34.358333

# %%
final_data = pd.merge(groupby_type_city,city_data, on ='city',how='left' )
final_data.head()
# Out:
#              city  (fare, sum)  (fare, mean)  (ride_id, count)  driver_count  \
# 0    Bradshawfurt       400.64     40.064000                10             7
# 1       Garzaport        72.37     24.123333                 3             7
# 2  Harringtonfort       200.82     33.470000                 6             4
# 3     Jessicaport       216.08     36.013333                 6             1
# 4      Lake Jamie       206.15     34.358333                 6             4
#
#     type
# 0  Rural
# 1  Rural
# 2  Rural
# 3  Rural
# 4  Rural

# %%
# reset index to be able to access 'type'
#groupby_type_city = groupby_type_city.reset_index()

# %%
# extract urban data
urban = groupby_type_city.loc[groupby_type_city['type']=='Urban',['driver_count','average_fare_per_city','ride_count_per_city']]
urban.head()

# %%
# extract suburban data
suburban = groupby_type_city.loc[groupby_type_city['type']=='Suburban',['driver_count','average_fare_per_city','ride_count_per_city']]
suburban.head()

# %%
# extract rural data
rural = groupby_type_city.loc[groupby_type_city['type']=='Rural',['driver_count','average_fare_per_city','ride_count_per_city']]
rural

# %%
# Build the scatter plots for each city types
plt.grid()


plt.scatter(urban["ride_count_per_city"], urban["average_fare_per_city"],  \
            marker="o", facecolors="salmon", edgecolors="black", s=urban["driver_count"], alpha=0.5, label=None)

plt.scatter(suburban["ride_count_per_city"], suburban["average_fare_per_city"], \
            marker="o", facecolors="skyblue", edgecolors="black", s=suburban["driver_count"], alpha=0.5 , label=None
          )

plt.scatter(rural["ride_count_per_city"], rural["average_fare_per_city"], \
            marker="o",facecolors="orange", edgecolors="black",s=rural["driver_count"], alpha=0.5 , label=None)

# create fake data for the legend
plt.scatter(0, 0,  \
            marker="o", facecolors="salmon", edgecolors="black", s=30, alpha=0.5, label = "Urban") 

plt.scatter(0, 0,  \
            marker="o", facecolors="skyblue", edgecolors="black", s=30, alpha=0.5, label = "Suburban") 

plt.scatter(0, 0, marker="o", facecolors="orange", edgecolors="black", s=30, alpha=0.5, label = "Rural") 

# add legend
plt.legend(numpoints=1, loc=1, borderpad=1, \
            frameon=True, framealpha=0.9, title="City type",scatterpoints = 1)

# set xlim and ylim
plt.ylim(19, 45)
plt.xlim(0, 41)

# add text outside the graph
# Incorporate a text label regarding circle size
plt.text(42,35,"test", fontsize=12)

# Incorporate the other graph properties
plt.title("Pyber ride Sharing Data (2016)")
plt.xlabel("Total number of rides (per city)")
plt.ylabel("Average fare ($)")
plt.tight_layout()
plt.show()

# %%
# Save Figure

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents

# Build Pie Charts

# Save Figure

# %%
# Show Figure
plt.show()
